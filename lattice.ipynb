# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pprint import pprint
with MPRester("OhzYzXS8KZ2GAhVz3g1zkqH8EJz32Y7X") as m:
    # Récupération de la structure du cristal KScO2
    structure = m.get_structure_by_material_id("mp-8188")
# Out:
# c:\Users\noaka\anaconda3\lib\site-packages\pymatgen\ext\matproj_legacy.py:168: UserWarning: You are using the legacy MPRester. This version of the MPRester will no longer be updated. To access the latest data with the new MPRester, obtain a new API key from https://materialsproject.org/api and consult the docs at https://docs.materialsproject.org/ for more information.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_45316\666208555.py in <module>
#       2 from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
#       3 from pprint import pprint
# ----> 4 with MPRester("P2FTs1l6Xaon8AOI") as m:
#       5     structure = m.get_structure_by_material_id("mp-28240")
#
# c:\Users\noaka\anaconda3\lib\site-packages\pymatgen\ext\matproj.py in __new__(cls, *args, **kwargs)
#     417             from pymatgen.ext.matproj_legacy import _MPResterLegacy
#     418
# --> 419             return _MPResterLegacy(*args, **kwargs)
#     420
#     421         try:
#
# c:\Users\noaka\anaconda3\lib\site-packages\pymatgen\ext\matproj_legacy.py in __init__(self, api_key, endpoint, notify_db_version, include_user_agent)
#     194         if notify_db_version:
#     195             yaml = YAML()
# --> 196             db_version = self.get_database_version()
#     197             logger.debug(f"Connection established to Materials Project database, version {db_version}.")
#     198
#
# c:\Users\noaka\anaconda3\lib\site-packages\pymatgen\ext\matproj_legacy.py in get_database_version(self)
#     288             str: database version
#     289         """
# --> 290         dct = self._make_request("/api_check")
#     291         return dct["version"]["db"]
#     292
#
# c:\Users\noaka\anaconda3\lib\site-packages\pymatgen\ext\matproj_legacy.py in _make_request(self, sub_url, payload, method, mp_decode)
#     259                 response = self.session.post(url, data=payload, verify=True)
#     260             else:
# --> 261                 response = self.session.get(url, params=payload, verify=True)
#     262             if response.status_code in [200, 400]:
#     263                 data = json.loads(response.text, cls=MontyDecoder) if mp_decode else json.loads(response.text)
#
# c:\Users\noaka\anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     600
#     601         kwargs.setdefault("allow_redirects", True)
# --> 602         return self.request("GET", url, **kwargs)
#     603
#     604     def options(self, url, **kwargs):
#
# c:\Users\noaka\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# c:\Users\noaka\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# c:\Users\noaka\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# c:\Users\noaka\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714
#     715             # Make the request on the httplib connection object.
# --> 716             httplib_response = self._make_request(
#     717                 conn,
#     718                 method,
#
# c:\Users\noaka\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     466                     # Python 3 (including for exceptions like SystemExit).
#     467                     # Otherwise it looks like a bug in the code.
# --> 468                     six.raise_from(e, None)
#     469         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\Users\noaka\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\noaka\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461                 # Python 3
#     462                 try:
# --> 463                     httplib_response = conn.getresponse()
#     464                 except BaseException as e:
#     465                     # Remove the TypeError from the exception chain in
#
# c:\Users\noaka\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# c:\Users\noaka\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# c:\Users\noaka\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# c:\Users\noaka\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\Users\noaka\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# c:\Users\noaka\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
struct = SpacegroupAnalyzer(structure)
print("Vecteurs de base du réseau direct :")
print(struct.get_lattice())
